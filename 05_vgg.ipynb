# %% [markdown]
# # 05 - VGG16 Classifier
#
# Fine-tunes a pre-trained **VGG16** (ImageNet) for 36-class fruits & vegetables classification.
#
# **Strategy**
# - Phase 1: freeze the base model, train the new classification head only.
# - Phase 2: unfreeze block5 (the last convolutional block) and fine-tune at a low LR.
#
# **Input pipeline:** images are loaded as `[0, 1]` float32. A `Lambda` layer inside the model
# scales them to `[0, 255]` then calls `vgg16.preprocess_input`, which subtracts ImageNet
# channel means and converts RGB → BGR — the format VGG16 was pre-trained on.

# %%
# %matplotlib inline
import sys
import json
from pathlib import Path
import random
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 100

# GPU memory growth (safe no-op if no GPU)
for gpu in tf.config.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)

print(f'Python     : {sys.version.split()[0]}')
print(f'TensorFlow : {tf.__version__}')
gpus = tf.config.list_physical_devices('GPU')
print(f'GPUs       : {[g.name for g in gpus] if gpus else "none — CPU only"}')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Python     : 3.10.0
# TensorFlow : 2.21.0
# GPUs       : none — CPU only

# %%
ROOT       = Path('.')
TRAIN_ROOT = ROOT / 'train'
TEST_ROOT  = ROOT / 'test'
PLOTS_DIR  = ROOT / 'plots'
PLOTS_DIR.mkdir(exist_ok=True)

IMG_SIZE     = (224, 224)
BATCH_SIZE   = 32
SEED         = 42
LR_HEAD      = 1e-3
LR_FINE      = 1e-5
EPOCHS_HEAD  = 10
EPOCHS_FINE  = 20
FINE_TUNE_AT = 15
DROPOUT      = 0.4
IMG_EXTS     = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

assert TRAIN_ROOT.exists(), 'train/ not found - run from project root'
assert TEST_ROOT.exists(),  'test/  not found - run from project root'

# %% [markdown]
# ## 1. Data Loading
#
# Functions copied verbatim from `00_preprocessing.ipynb` — same `CLASS_NAMES` order is critical.

# %%
def discover_classes(root: Path) -> dict:
    """Flatten fruit/vegetable grouping layer -> {class_name: path}."""
    classes = {}
    for cat_dir in sorted(root.iterdir()):
        if not cat_dir.is_dir():
            continue
        for cls_dir in sorted(cat_dir.iterdir()):
            if cls_dir.is_dir():
                classes[cls_dir.name.lower()] = cls_dir
    return classes


def build_file_list(root: Path, class_to_idx: dict) -> tuple:
    """Return (file_path_strings, int_labels) from the nested fruit/veg structure."""
    paths, labels = [], []
    for cat_dir in sorted(root.iterdir()):
        if not cat_dir.is_dir():
            continue
        for cls_dir in sorted(cat_dir.iterdir()):
            if not cls_dir.is_dir():
                continue
            cls = cls_dir.name.lower()
            if cls not in class_to_idx:
                continue
            idx = class_to_idx[cls]
            for f in cls_dir.iterdir():
                if f.suffix.lower() in IMG_EXTS:
                    paths.append(str(f))
                    labels.append(idx)
    return paths, labels


def make_tf_dataset(file_paths, int_labels, n_classes,
                    img_size=(224, 224), batch_size=32,
                    augment=False, shuffle=True, seed=42):
    """Batched tf.data.Dataset. Outputs float32 images in [0, 1]."""

    def load(path, label):
        raw = tf.io.read_file(path)
        img = tf.image.decode_image(raw, channels=3, expand_animations=False)
        img.set_shape([None, None, 3])
        img = tf.image.resize(img, img_size)
        img = tf.cast(img, tf.float32) / 255.0
        return img, tf.one_hot(label, n_classes)

    def augment_fn(img, label):
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_brightness(img, max_delta=0.15)
        img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
        img = tf.image.random_saturation(img, lower=0.85, upper=1.15)
        img = tf.clip_by_value(img, 0.0, 1.0)
        return img, label

    ds = tf.data.Dataset.from_tensor_slices((file_paths, int_labels))
    if shuffle:
        ds = ds.shuffle(len(file_paths), seed=seed)
    ds = ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
    if augment:
        ds = ds.map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
train_classes = discover_classes(TRAIN_ROOT)
CLASS_NAMES   = sorted(train_classes.keys())
N_CLASSES     = len(CLASS_NAMES)
CLASS_TO_IDX  = {c: i for i, c in enumerate(CLASS_NAMES)}

all_paths, all_labels = build_file_list(TRAIN_ROOT, CLASS_TO_IDX)
train_paths, val_paths, train_labels, val_labels = train_test_split(
    all_paths, all_labels,
    test_size=0.2, stratify=all_labels, random_state=SEED
)
test_paths, test_labels = build_file_list(TEST_ROOT, CLASS_TO_IDX)

train_ds = make_tf_dataset(train_paths, train_labels, N_CLASSES,
                           img_size=IMG_SIZE, batch_size=BATCH_SIZE,
                           augment=True,  shuffle=True,  seed=SEED)
val_ds   = make_tf_dataset(val_paths,   val_labels,   N_CLASSES,
                           img_size=IMG_SIZE, batch_size=BATCH_SIZE,
                           augment=False, shuffle=False)
test_ds  = make_tf_dataset(test_paths,  test_labels,  N_CLASSES,
                           img_size=IMG_SIZE, batch_size=BATCH_SIZE,
                           augment=False, shuffle=False)

print(f'Classes     : {N_CLASSES}')
print(f'Train imgs  : {len(train_paths)}')
print(f'Val   imgs  : {len(val_paths)}')
print(f'Test  imgs  : {len(test_paths)}')

# Smoke-test one batch
for x, y in train_ds.take(1):
    print(f'Batch shape : {x.shape}  labels: {y.shape}')
    print(f'Pixel range : [{x.numpy().min():.3f}, {x.numpy().max():.3f}]')
# Out:
# Classes     : 36
# Train imgs  : 2492
# Val   imgs  : 623
# Test  imgs  : 359
# Batch shape : (32, 224, 224, 3)  labels: (32, 36)
# Pixel range : [0.000, 1.000]

# %% [markdown]
# ## 2. Model Architecture
#
# ```
# Input (224, 224, 3)  [0, 1]
#   └─ Lambda: ×255 → vgg16.preprocess_input   → BGR, channel-mean-subtracted
#   └─ VGG16 base (no top)                     → (7, 7, 512)
#   └─ GlobalAveragePooling2D                  → (512,)
#   └─ Dense(256, relu)
#   └─ BatchNormalization
#   └─ Dropout(0.4)
#   └─ Dense(36, softmax)
# ```
#
# VGG16 layers (no top): 19 total (input + 13 conv + 5 pool).
# Fine-tuning unfreeze from index 15 = block5_conv1 onward (last 4 layers).

# %%
# Load ImageNet base — no top classifier, frozen initially
base_model = tf.keras.applications.VGG16(
    input_shape=(*IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False
print(f'Base model layers : {len(base_model.layers)}')
for i, layer in enumerate(base_model.layers):
    print(f'  [{i:2d}] {layer.name}')

# Build full model
inputs  = tf.keras.Input(shape=(*IMG_SIZE, 3), name='input_image')
# Scale [0,1] → [0,255] then apply VGG16 channel-mean subtraction + RGB→BGR
x       = tf.keras.layers.Lambda(
    lambda img: tf.keras.applications.vgg16.preprocess_input(img * 255.0),
    name='preprocess'
)(inputs)
x       = base_model(x, training=False)
x       = tf.keras.layers.GlobalAveragePooling2D(name='gap')(x)
x       = tf.keras.layers.Dense(256, activation='relu', name='head_dense')(x)
x       = tf.keras.layers.BatchNormalization(name='head_bn')(x)
x       = tf.keras.layers.Dropout(DROPOUT, name='head_dropout')(x)
outputs = tf.keras.layers.Dense(N_CLASSES, activation='softmax', name='predictions')(x)

model = tf.keras.Model(inputs, outputs, name='vgg16_36cls')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 30s 1us/step
# Base model layers : 19
#   [ 0] input_layer
#   [ 1] block1_conv1
#   [ 2] block1_conv2
#   [ 3] block1_pool
#   [ 4] block2_conv1
#   [ 5] block2_conv2
#   [ 6] block2_pool
#   [ 7] block3_conv1
#   [ 8] block3_conv2
#   [ 9] block3_conv3
#   [10] block3_pool
#   [11] block4_conv1
#   [12] block4_conv2
#   [13] block4_conv3
#   [14] block4_pool
#   [15] block5_conv1
#   [16] block5_conv2
#   [17] block5_conv3
#   [18] block5_pool
# WARNING:tensorflow:From c:\fvc_venv\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
model.summary(show_trainable=True)

print(f'\nTrainable params     : {sum(tf.size(w).numpy() for w in model.trainable_weights):,}')
print(f'Non-trainable params : {sum(tf.size(w).numpy() for w in model.non_trainable_weights):,}')
# Out:
# Model: "vgg16_36cls"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_image (InputLayer)    │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ preprocess (Lambda)         │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ vgg16 (Functional)          │ (None, 7, 7, 512)     │ 14,714,688 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ gap                         │ (None, 512)           │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ head_dense (Dense)          │ (None, 256)           │    131,328 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ head_bn                     │ (None, 256)           │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ head_dropout (Dropout)      │ (None, 256)           │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ predictions (Dense)         │ (None, 36)            │      9,252 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 14,856,292 (56.67 MB)
#  Trainable params: 141,092 (551.14 KB)
#  Non-trainable params: 14,715,200 (56.13 MB)
# Trainable params     : 141,092
# Non-trainable params : 14,715,200

# %% [markdown]
# ## 3. Phase 1 — Feature Extraction
#
# VGG16 base is **frozen**. Only the new head (Dense(256) → BN → Dropout → Dense(36)) is trained.
# This quickly adapts the classifier to the 36-class problem without disturbing ImageNet features.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_HEAD),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks_ph1 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=5,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3,
        min_lr=1e-6, verbose=1
    ),
]

print('=== Phase 1: training head only ===')
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_HEAD,
    callbacks=callbacks_ph1,
    verbose=1
)

val_acc_ph1 = max(history1.history['val_accuracy'])
print(f'\nBest val accuracy (Phase 1): {val_acc_ph1:.4f}')
# Out:
# === Phase 1: training head only ===
# Epoch 1/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 313s 4s/step - accuracy: 0.4005 - loss: 2.4042 - val_accuracy: 0.6758 - val_loss: 1.1363 - learning_rate: 0.0010
# Epoch 2/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 266s 3s/step - accuracy: 0.7063 - loss: 1.0641 - val_accuracy: 0.7592 - val_loss: 0.8665 - learning_rate: 0.0010
# Epoch 3/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 217s 3s/step - accuracy: 0.7761 - loss: 0.7612 - val_accuracy: 0.7897 - val_loss: 0.7416 - learning_rate: 0.0010
# Epoch 4/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - accuracy: 0.8283 - loss: 0.5916 - val_accuracy: 0.7865 - val_loss: 0.7126 - learning_rate: 0.0010
# Epoch 5/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - accuracy: 0.8652 - loss: 0.4789 - val_accuracy: 0.7849 - val_loss: 0.6763 - learning_rate: 0.0010
# Epoch 6/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.8724 - loss: 0.4261 - val_accuracy: 0.8010 - val_loss: 0.6696 - learning_rate: 0.0010
# Epoch 7/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 214s 3s/step - accuracy: 0.8949 - loss: 0.3620 - val_accuracy: 0.7849 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 8/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 222s 3s/step - accuracy: 0.9121 - loss: 0.2961 - val_accuracy: 0.8090 - val_loss: 0.6621 - learning_rate: 0.0010
# Epoch 9/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 244s 3s/step - accuracy: 0.9217 - loss: 0.2637 - val_accuracy: 0.7945 - val_loss: 0.6730 - learning_rate: 0.0010
# Epoch 10/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 271s 3s/step - accuracy: 0.9330 - loss: 0.2218 - val_accuracy: 0.7913 - val_loss: 0.7043 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 8.
#
# Best val accuracy (Phase 1): 0.8090

# %% [markdown]
# ## 4. Phase 2 — Fine-tuning
#
# Unfreeze VGG16 block5 (layers 15–18: `block5_conv1`, `block5_conv2`, `block5_conv3`, `block5_pool`).
# Retrain end-to-end at a much lower learning rate to preserve early ImageNet features.

# %%
# Unfreeze the base model, then re-freeze everything before FINE_TUNE_AT
base_model.trainable = True
for layer in base_model.layers[:FINE_TUNE_AT]:
    layer.trainable = False

trainable_count   = sum(1 for l in base_model.layers if l.trainable)
untrainable_count = sum(1 for l in base_model.layers if not l.trainable)
print(f'Base model  — trainable: {trainable_count},  frozen: {untrainable_count}')
print(f'Fine-tuning layers [{FINE_TUNE_AT}:]')
for layer in base_model.layers[FINE_TUNE_AT:]:
    print(f'  {layer.name}')
# Out:
# Base model  — trainable: 4,  frozen: 15
# Fine-tuning layers [15:]
#   block5_conv1
#   block5_conv2
#   block5_conv3
#   block5_pool

# %%
# Must recompile after changing trainable states
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_FINE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks_ph2 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=7,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3,
        min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'vgg_best.keras',
        monitor='val_accuracy', save_best_only=True, verbose=0
    ),
]

print('=== Phase 2: fine-tuning ===')
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_FINE,
    callbacks=callbacks_ph2,
    verbose=1
)

val_acc_ph2 = max(history2.history['val_accuracy'])
print(f'\nBest val accuracy (Phase 2): {val_acc_ph2:.4f}')
# Out:
# === Phase 2: fine-tuning ===
# Epoch 1/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 279s 4s/step - accuracy: 0.9306 - loss: 0.2498 - val_accuracy: 0.7994 - val_loss: 0.6534 - learning_rate: 1.0000e-05
# Epoch 2/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 253s 3s/step - accuracy: 0.9446 - loss: 0.2065 - val_accuracy: 0.8058 - val_loss: 0.6523 - learning_rate: 1.0000e-05
# Epoch 3/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 363s 5s/step - accuracy: 0.9551 - loss: 0.1688 - val_accuracy: 0.7978 - val_loss: 0.6701 - learning_rate: 1.0000e-05
# Epoch 4/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 251s 3s/step - accuracy: 0.9635 - loss: 0.1568 - val_accuracy: 0.7994 - val_loss: 0.6494 - learning_rate: 1.0000e-05
# Epoch 5/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 241s 3s/step - accuracy: 0.9691 - loss: 0.1380 - val_accuracy: 0.8090 - val_loss: 0.6442 - learning_rate: 1.0000e-05
# Epoch 6/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 261s 3s/step - accuracy: 0.9739 - loss: 0.1355 - val_accuracy: 0.7929 - val_loss: 0.6538 - learning_rate: 1.0000e-05
# Epoch 7/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 245s 3s/step - accuracy: 0.9711 - loss: 0.1238 - val_accuracy: 0.8154 - val_loss: 0.6423 - learning_rate: 1.0000e-05
# Epoch 8/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 319s 4s/step - accuracy: 0.9767 - loss: 0.1085 - val_accuracy: 0.8170 - val_loss: 0.6310 - learning_rate: 1.0000e-05
# Epoch 9/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 321s 4s/step - accuracy: 0.9803 - loss: 0.1069 - val_accuracy: 0.8122 - val_loss: 0.6404 - learning_rate: 1.0000e-05
# Epoch 10/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 392s 5s/step - accuracy: 0.9827 - loss: 0.0994 - val_accuracy: 0.8202 - val_loss: 0.6275 - learning_rate: 1.0000e-05
# Epoch 11/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 291s 4s/step - accuracy: 0.9815 - loss: 0.0926 - val_accuracy: 0.8122 - val_loss: 0.6299 - learning_rate: 1.0000e-05
# Epoch 12/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 275s 4s/step - accuracy: 0.9839 - loss: 0.0827 - val_accuracy: 0.8186 - val_loss: 0.6288 - learning_rate: 1.0000e-05
# Epoch 13/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 258s 3s/step - accuracy: 0.9868 - loss: 0.0859 - val_accuracy: 0.8186 - val_loss: 0.6187 - learning_rate: 1.0000e-05
# Epoch 14/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 314s 4s/step - accuracy: 0.9848 - loss: 0.0775 - val_accuracy: 0.8138 - val_loss: 0.6295 - learning_rate: 1.0000e-05
# Epoch 15/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 284s 4s/step - accuracy: 0.9856 - loss: 0.0739 - val_accuracy: 0.8170 - val_loss: 0.6369 - learning_rate: 1.0000e-05
# Epoch 16/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9924 - loss: 0.0622
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.9884 - loss: 0.0683 - val_accuracy: 0.8315 - val_loss: 0.6229 - learning_rate: 1.0000e-05
# Epoch 17/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 264s 3s/step - accuracy: 0.9924 - loss: 0.0600 - val_accuracy: 0.8186 - val_loss: 0.6258 - learning_rate: 5.0000e-06
# Epoch 18/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step - accuracy: 0.9904 - loss: 0.0572 - val_accuracy: 0.8234 - val_loss: 0.6342 - learning_rate: 5.0000e-06
# Epoch 19/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9923 - loss: 0.0519
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 270s 3s/step - accuracy: 0.9932 - loss: 0.0519 - val_accuracy: 0.8202 - val_loss: 0.6298 - learning_rate: 5.0000e-06
# Epoch 20/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 347s 4s/step - accuracy: 0.9952 - loss: 0.0523 - val_accuracy: 0.8186 - val_loss: 0.6373 - learning_rate: 2.5000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# Best val accuracy (Phase 2): 0.8315

# %% [markdown]
# ## 5. Training History

# %%
acc      = history1.history['accuracy']     + history2.history['accuracy']
val_acc  = history1.history['val_accuracy'] + history2.history['val_accuracy']
loss     = history1.history['loss']         + history2.history['loss']
val_loss = history1.history['val_loss']     + history2.history['val_loss']
p1_end   = len(history1.history['accuracy'])
epochs   = range(1, len(acc) + 1)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, train_vals, val_vals, title, ylabel in zip(
    axes,
    [acc,  loss],
    [val_acc, val_loss],
    ['Accuracy', 'Loss'],
    ['accuracy', 'loss']
):
    ax.plot(epochs, train_vals, label='train')
    ax.plot(epochs, val_vals,   label='val')
    ax.axvline(x=p1_end + 0.5, color='grey', linestyle='--', linewidth=1,
               label='Phase 1 → 2')
    ax.set(title=title, xlabel='Epoch', ylabel=ylabel)
    ax.legend()

plt.suptitle('VGG16 - Training History', fontsize=13)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'vgg_history.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Test Set Evaluation

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f'Test loss     : {test_loss:.4f}')
print(f'Test accuracy : {test_acc:.4f}  ({test_acc*100:.2f}%)')
# Out:
# Test loss     : 0.1353
# Test accuracy : 0.9666  (96.66%)

# %%
# Collect all true labels and predictions from test_ds
y_true = np.concatenate(
    [np.argmax(lbl.numpy(), axis=1) for _, lbl in test_ds]
)
y_pred = np.argmax(model.predict(test_ds, verbose=0), axis=1)

print('=== Classification Report ===')
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=3))
# Out:
# === Classification Report ===
#                precision    recall  f1-score   support
#
#         apple      0.818     0.900     0.857        10
#        banana      1.000     0.778     0.875         9
#      beetroot      1.000     1.000     1.000        10
#   bell pepper      0.909     1.000     0.952        10
#       cabbage      1.000     1.000     1.000        10
#      capsicum      1.000     0.900     0.947        10
#        carrot      1.000     0.900     0.947        10
#   cauliflower      1.000     1.000     1.000        10
# chilli pepper      1.000     1.000     1.000        10
#          corn      0.818     0.900     0.857        10
#      cucumber      1.000     1.000     1.000        10
#      eggplant      1.000     0.900     0.947        10
#        garlic      1.000     1.000     1.000        10
#        ginger      1.000     1.000     1.000        10
#        grapes      1.000     1.000     1.000        10
#      jalepeno      1.000     1.000     1.000        10
#          kiwi      1.000     1.000     1.000        10
#         lemon      1.000     1.000     1.000        10
#       lettuce      1.000     1.000     1.000        10
#         mango      1.000     1.000     1.000        10
#         onion      1.000     1.000     1.000        10
#        orange      1.000     1.000     1.000        10
#       paprika      1.000     1.000     1.000        10
#          pear      1.000     1.000     1.000        10
#          peas      0.909     1.000     0.952        10
#     pineapple      1.000     1.000     1.000        10
#   pomegranate      0.909     1.000     0.952        10
#        potato      0.889     0.800     0.842        10
#       raddish      0.833     1.000     0.909        10
#     soy beans      1.000     1.000     1.000        10
#       spinach      1.000     1.000     1.000        10
#     sweetcorn      0.889     0.800     0.842        10
#   sweetpotato      1.000     0.900     0.947        10
#        tomato      0.909     1.000     0.952        10
#        turnip      1.000     1.000     1.000        10
#    watermelon      1.000     1.000     1.000        10
#
#      accuracy                          0.967       359
#     macro avg      0.969     0.966     0.966       359
#  weighted avg      0.969     0.967     0.966       359

# %%
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
    linewidths=0.4, ax=ax, annot_kws={'size': 7}
)
ax.set(xlabel='Predicted', ylabel='True',
       title='Confusion Matrix - VGG16')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0,  fontsize=8)
plt.tight_layout()
plt.savefig(PLOTS_DIR / 'vgg_confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. Save Model

# %%
model.save('vgg.keras')
print('Model saved → vgg.keras')

# Usage reminder
print('\nTo reload:')
print('  model = tf.keras.models.load_model("vgg.keras")')
print('  # model expects float32 images in [0, 1] - preprocessing is built in')
# Out:
# Model saved -> vgg.keras
#
# To reload:
#   model = tf.keras.models.load_model("vgg.keras")
#   # model expects float32 images in [0, 1] - preprocessing is built in

# %% [markdown]
# ## Summary
#
# | Item | Value |
# |------|-------|
# | Architecture | VGG16 (ImageNet weights) |
# | Input | 224 × 224 × 3, float32 in [0, 1] |
# | Preprocessing in model | ×255 → vgg16.preprocess_input (BGR, mean-sub) |
# | Classes | 36 |
# | Head | GAP → Dense(256, relu) → BN → Dropout(0.4) → Dense(36, softmax) |
# | Phase 1 | Frozen base, Adam(1e-3), up to 10 epochs |
# | Phase 2 | Unfreeze block5 (layers 15+), Adam(1e-5), up to 20 epochs |
# | Augmentation | flip, brightness, contrast, saturation |
# | Saved model | `vgg.keras` (accepts [0,1] input) |
